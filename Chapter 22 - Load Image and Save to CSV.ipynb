# %%
from skimage import io
import matplotlib.pylab as plt
import numpy as np

# %%
image = io.imread('https://upload.wikimedia.org/wikipedia/commons/5/50/Vd-Orig.png')

# %%
image.shape
# Out:
# (100, 100, 3)

# %%
plt.matshow(image[:, :, 2])

# %%
print(image[0:5, 0:5, 0])
# Out:
# [[132 130 127 126 127]
#  [130 141 128 150 146]
#  [138 146 156 175 146]
#  [162 164 151 180 154]
#  [155 158 152 182 158]]

# %%
np.savetxt('Chapter22-blackwhite-image.csv', image[:, :, 0], delimiter=',')

# %%
plt.matshow(image[:, :, 2], cmap='gray')
plt.matshow(image[:, :, 2], cmap='gray_r')
